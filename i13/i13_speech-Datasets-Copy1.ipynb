# %%
from IPython import display

# File Processing
import glob
import os
from os.path import isdir, join
from pathlib import Path

# Math
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import math
from scipy import signal
from scipy.io import wavfile

# Data Plotting and Visualizations
from PIL import Image
from matplotlib import cm
from matplotlib import gridspec
from matplotlib import pyplot as plt
# %matplotlib inline 
import seaborn as sns

# Sklearn Metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# Tensorflow
import tensorflow as tf
from tensorflow.python.data import Dataset
import tensorflow_hub as hub

tf.logging.set_verbosity(tf.logging.ERROR)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 40
pd.options.display.float_format = '{:.2f}'.format

# %%
train_audio_folder = './train/audio/'
train_spect_tmp_folder = './train/spect_tmp/'
train_spect_folder = './train/spect/'

# %%
subfolders = [x for x in os.listdir(train_audio_folder) if os.path.isdir(train_audio_folder + '/' + x)]

# %%
def create_label_subfolders(path, subfolders):
    for x in subfolders:
        subfolder_path = path + x
        if os.path.exists(subfolder_path):
            print("%s already exists in this folder" % x)
        else: 
            os.makedirs(subfolder_path)
            print("%s folder created at %s" % (x, subfolder_path))

# %%
create_label_subfolders(train_spect_folder, subfolders)
# Out:
# zero already exists in this folder
# six already exists in this folder
# happy already exists in this folder
# on already exists in this folder
# left already exists in this folder
# one already exists in this folder
# no already exists in this folder
# go already exists in this folder
# _background_noise_ already exists in this folder
# off already exists in this folder
# tree already exists in this folder
# bed already exists in this folder
# cat already exists in this folder
# up already exists in this folder
# eight already exists in this folder
# marvin already exists in this folder
# stop already exists in this folder
# yes already exists in this folder
# three already exists in this folder
# down already exists in this folder
# nine already exists in this folder
# four already exists in this folder
# seven already exists in this folder
# sheila already exists in this folder
# dog already exists in this folder
# right already exists in this folder
# two already exists in this folder
# wow already exists in this folder
# house already exists in this folder
# bird already exists in this folder
# five already exists in this folder

# %%
def log_specgram2(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, _, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, np.log(spec.T.astype(np.float32) + eps)

# %%
def create_spectrogram_file(subfolder, filename):
    tmp_img = './train/spect_tmp/' + filename[:-4] + "_" + subfolder + "_tmp.jpg"
    spect_img = './train/spect/' + subfolder + '/' + filename[:-4] + "_spect.jpg"
    
    sample_rate, samples = wavfile.read('./train/audio/' + subfolder + '/' + filename)
    freqs, times, spectrogram = log_specgram(samples, sample_rate)
    mean = np.mean(spectrogram, axis=0)
    std = np.std(spectrogram, axis=0)
    spectrogram = (spectrogram - mean) / std
    
    fig = plt.figure(figsize=(14, 8))
    ax2 = fig.add_subplot(211)
    ax2.imsave(spectrogram.T, aspect='auto', origin='lower', 
               extent=[times.min(), times.max(), freqs.min(), freqs.max()])
    ax2.set_axis_off()
    
    plt.savefig(tmp_img, bbox_inches='tight', transparent=True)
    plt.close(fig)
    fig.clf()
    
    size = 224, 224
    im = Image.open(tmp_img).resize(size)
    os.remove(tmp_img)
    im.save(spect_img)

# %%
def create_spectrogram_tmp_file(subfolder, filename):
    tmp_img = './train/spect_tmp/' + filename[:-4] + "_" + subfolder + "_tmp.jpg"
    sample_rate, samples = wavfile.read('./train/audio/' + subfolder + '/' + filename)
    _, spectrogram = log_specgram(samples, sample_rate)
    plt.imsave(tmp_img, spectrogram.T, origin='lower')

# %%
# %%time
total = 0
for x in subfolders:
    subfolder_wav_files = [x for x in os.listdir(train_audio_folder + x) if '.wav' in x]
    len_subfolder = len(subfolder_wav_files)
    total += len_subfolder
    for y in range(len_subfolder):  
        create_spectrogram_tmp_file(x, subfolder_wav_files[y])
        if y % 100 == 0:
            print("%d of %d images in %s processed" % (y, len_subfolder, x))
    print('file count in %s: %d' % (x, len_subfolder))
print('total file count: %d' % (total))
# Out:
# 0 of 2376 images in zero processed
# 100 of 2376 images in zero processed
# 200 of 2376 images in zero processed
# 300 of 2376 images in zero processed
# 400 of 2376 images in zero processed
# 500 of 2376 images in zero processed
# 600 of 2376 images in zero processed
# 700 of 2376 images in zero processed
# 800 of 2376 images in zero processed
# 900 of 2376 images in zero processed
# 1000 of 2376 images in zero processed
# 1100 of 2376 images in zero processed
# 1200 of 2376 images in zero processed
# 1300 of 2376 images in zero processed
# 1400 of 2376 images in zero processed
# 1500 of 2376 images in zero processed
# 1600 of 2376 images in zero processed
# 1700 of 2376 images in zero processed
# 1800 of 2376 images in zero processed
# 1900 of 2376 images in zero processed
# 2000 of 2376 images in zero processed
# 2100 of 2376 images in zero processed
# 2200 of 2376 images in zero processed
# 2300 of 2376 images in zero processed
# file count in zero: 2376
# 0 of 2369 images in six processed
# 100 of 2369 images in six processed
# 200 of 2369 images in six processed
# 300 of 2369 images in six processed
# 400 of 2369 images in six processed
# 500 of 2369 images in six processed
# 600 of 2369 images in six processed
# 700 of 2369 images in six processed
# 800 of 2369 images in six processed
# 900 of 2369 images in six processed
# 1000 of 2369 images in six processed
# 1100 of 2369 images in six processed
# 1200 of 2369 images in six processed
# 1300 of 2369 images in six processed
# 1400 of 2369 images in six processed
# 1500 of 2369 images in six processed
# 1600 of 2369 images in six processed
# 1700 of 2369 images in six processed
# 1800 of 2369 images in six processed
# 1900 of 2369 images in six processed
# 2000 of 2369 images in six processed
# 2100 of 2369 images in six processed
# 2200 of 2369 images in six processed
# 2300 of 2369 images in six processed
# file count in six: 2369
# 0 of 1742 images in happy processed
# 100 of 1742 images in happy processed
# 200 of 1742 images in happy processed
# 300 of 1742 images in happy processed
# 400 of 1742 images in happy processed
# 500 of 1742 images in happy processed
# 600 of 1742 images in happy processed
# 700 of 1742 images in happy processed
# 800 of 1742 images in happy processed
# 900 of 1742 images in happy processed
# 1000 of 1742 images in happy processed
# 1100 of 1742 images in happy processed
# 1200 of 1742 images in happy processed
# 1300 of 1742 images in happy processed
# 1400 of 1742 images in happy processed
# 1500 of 1742 images in happy processed
# 1600 of 1742 images in happy processed
# 1700 of 1742 images in happy processed
# file count in happy: 1742
# 0 of 2367 images in on processed
# 100 of 2367 images in on processed
# 200 of 2367 images in on processed
# 300 of 2367 images in on processed
# 400 of 2367 images in on processed
# 500 of 2367 images in on processed
# 600 of 2367 images in on processed
# 700 of 2367 images in on processed
# 800 of 2367 images in on processed
# 900 of 2367 images in on processed
# 1000 of 2367 images in on processed
# 1100 of 2367 images in on processed
# 1200 of 2367 images in on processed
# 1300 of 2367 images in on processed
# 1400 of 2367 images in on processed
# 1500 of 2367 images in on processed
# 1600 of 2367 images in on processed
# 1700 of 2367 images in on processed
# 1800 of 2367 images in on processed
# 1900 of 2367 images in on processed
# 2000 of 2367 images in on processed
# 2100 of 2367 images in on processed
# 2200 of 2367 images in on processed
# 2300 of 2367 images in on processed
# file count in on: 2367
# 0 of 2353 images in left processed
# 100 of 2353 images in left processed
# 200 of 2353 images in left processed
# 300 of 2353 images in left processed
# 400 of 2353 images in left processed
# 500 of 2353 images in left processed
# 600 of 2353 images in left processed
# 700 of 2353 images in left processed
# 800 of 2353 images in left processed
# 900 of 2353 images in left processed
# 1000 of 2353 images in left processed
# 1100 of 2353 images in left processed
# 1200 of 2353 images in left processed
# 1300 of 2353 images in left processed
# 1400 of 2353 images in left processed
# 1500 of 2353 images in left processed
# 1600 of 2353 images in left processed
# 1700 of 2353 images in left processed
# 1800 of 2353 images in left processed
# 1900 of 2353 images in left processed
# 2000 of 2353 images in left processed
# 2100 of 2353 images in left processed
# 2200 of 2353 images in left processed
# 2300 of 2353 images in left processed
# file count in left: 2353
# 0 of 2370 images in one processed
# 100 of 2370 images in one processed
# 200 of 2370 images in one processed
# 300 of 2370 images in one processed
# 400 of 2370 images in one processed
# 500 of 2370 images in one processed
# 600 of 2370 images in one processed
# 700 of 2370 images in one processed
# 800 of 2370 images in one processed
# 900 of 2370 images in one processed
# 1000 of 2370 images in one processed
# 1100 of 2370 images in one processed
# 1200 of 2370 images in one processed
# 1300 of 2370 images in one processed
# 1400 of 2370 images in one processed
# 1500 of 2370 images in one processed
# 1600 of 2370 images in one processed
# 1700 of 2370 images in one processed
# 1800 of 2370 images in one processed
# 1900 of 2370 images in one processed
# 2000 of 2370 images in one processed
# 2100 of 2370 images in one processed
# 2200 of 2370 images in one processed
# 2300 of 2370 images in one processed
# file count in one: 2370
# 0 of 2375 images in no processed
# 100 of 2375 images in no processed
# 200 of 2375 images in no processed
# 300 of 2375 images in no processed
# 400 of 2375 images in no processed
# 500 of 2375 images in no processed
# 600 of 2375 images in no processed
# 700 of 2375 images in no processed
# 800 of 2375 images in no processed
# 900 of 2375 images in no processed
# 1000 of 2375 images in no processed
# 1100 of 2375 images in no processed
# 1200 of 2375 images in no processed
# 1300 of 2375 images in no processed
# 1400 of 2375 images in no processed
# 1500 of 2375 images in no processed
# 1600 of 2375 images in no processed
# 1700 of 2375 images in no processed
# 1800 of 2375 images in no processed
# 1900 of 2375 images in no processed
# 2000 of 2375 images in no processed
# 2100 of 2375 images in no processed
# 2200 of 2375 images in no processed
# 2300 of 2375 images in no processed
# file count in no: 2375
# 0 of 2372 images in go processed
# 100 of 2372 images in go processed
# 200 of 2372 images in go processed
# 300 of 2372 images in go processed
# 400 of 2372 images in go processed
# 500 of 2372 images in go processed
# 600 of 2372 images in go processed
# 700 of 2372 images in go processed
# 800 of 2372 images in go processed
# 900 of 2372 images in go processed
# 1000 of 2372 images in go processed
# 1100 of 2372 images in go processed
# 1200 of 2372 images in go processed
# 1300 of 2372 images in go processed
# 1400 of 2372 images in go processed
# 1500 of 2372 images in go processed
# 1600 of 2372 images in go processed
# 1700 of 2372 images in go processed
# 1800 of 2372 images in go processed
# 1900 of 2372 images in go processed
# 2000 of 2372 images in go processed
# 2100 of 2372 images in go processed
# 2200 of 2372 images in go processed
# 2300 of 2372 images in go processed
# file count in go: 2372
# 0 of 6 images in _background_noise_ processed
# /home/girlybit/anaconda3/lib/python3.5/site-packages/scipy/io/wavfile.py:221: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# file count in _background_noise_: 6
# 0 of 2357 images in off processed
# 100 of 2357 images in off processed
# 200 of 2357 images in off processed
# 300 of 2357 images in off processed
# 400 of 2357 images in off processed
# 500 of 2357 images in off processed
# 600 of 2357 images in off processed
# 700 of 2357 images in off processed
# 800 of 2357 images in off processed
# 900 of 2357 images in off processed
# 1000 of 2357 images in off processed
# 1100 of 2357 images in off processed
# 1200 of 2357 images in off processed
# 1300 of 2357 images in off processed
# 1400 of 2357 images in off processed
# 1500 of 2357 images in off processed
# 1600 of 2357 images in off processed
# 1700 of 2357 images in off processed
# 1800 of 2357 images in off processed
# 1900 of 2357 images in off processed
# 2000 of 2357 images in off processed
# 2100 of 2357 images in off processed
# 2200 of 2357 images in off processed
# 2300 of 2357 images in off processed
# file count in off: 2357
# 0 of 1733 images in tree processed
# 100 of 1733 images in tree processed
# 200 of 1733 images in tree processed
# 300 of 1733 images in tree processed
# 400 of 1733 images in tree processed
# 500 of 1733 images in tree processed
# 600 of 1733 images in tree processed
# 700 of 1733 images in tree processed
# 800 of 1733 images in tree processed
# 900 of 1733 images in tree processed
# 1000 of 1733 images in tree processed
# 1100 of 1733 images in tree processed
# 1200 of 1733 images in tree processed
# 1300 of 1733 images in tree processed
# 1400 of 1733 images in tree processed
# 1500 of 1733 images in tree processed
# 1600 of 1733 images in tree processed
# 1700 of 1733 images in tree processed
# file count in tree: 1733
# 0 of 1713 images in bed processed
# 100 of 1713 images in bed processed
# 200 of 1713 images in bed processed
# 300 of 1713 images in bed processed
# 400 of 1713 images in bed processed
# 500 of 1713 images in bed processed
# 600 of 1713 images in bed processed
# 700 of 1713 images in bed processed
# 800 of 1713 images in bed processed
# 900 of 1713 images in bed processed
# 1000 of 1713 images in bed processed
# 1100 of 1713 images in bed processed
# 1200 of 1713 images in bed processed
# 1300 of 1713 images in bed processed
# 1400 of 1713 images in bed processed
# 1500 of 1713 images in bed processed
# 1600 of 1713 images in bed processed
# 1700 of 1713 images in bed processed
# file count in bed: 1713
# 0 of 1733 images in cat processed
# 100 of 1733 images in cat processed
# 200 of 1733 images in cat processed
# 300 of 1733 images in cat processed
# 400 of 1733 images in cat processed
# 500 of 1733 images in cat processed
# 600 of 1733 images in cat processed
# 700 of 1733 images in cat processed
# 800 of 1733 images in cat processed
# 900 of 1733 images in cat processed
# 1000 of 1733 images in cat processed
# 1100 of 1733 images in cat processed
# 1200 of 1733 images in cat processed
# 1300 of 1733 images in cat processed
# 1400 of 1733 images in cat processed
# 1500 of 1733 images in cat processed
# 1600 of 1733 images in cat processed
# 1700 of 1733 images in cat processed
# file count in cat: 1733
# 0 of 2375 images in up processed
# 100 of 2375 images in up processed
# 200 of 2375 images in up processed
# 300 of 2375 images in up processed
# 400 of 2375 images in up processed
# 500 of 2375 images in up processed
# 600 of 2375 images in up processed
# 700 of 2375 images in up processed
# 800 of 2375 images in up processed
# 900 of 2375 images in up processed
# 1000 of 2375 images in up processed
# 1100 of 2375 images in up processed
# 1200 of 2375 images in up processed
# 1300 of 2375 images in up processed
# 1400 of 2375 images in up processed
# 1500 of 2375 images in up processed
# 1600 of 2375 images in up processed
# 1700 of 2375 images in up processed
# 1800 of 2375 images in up processed
# 1900 of 2375 images in up processed
# 2000 of 2375 images in up processed
# 2100 of 2375 images in up processed
# 2200 of 2375 images in up processed
# 2300 of 2375 images in up processed
# file count in up: 2375
# 0 of 2352 images in eight processed
# 100 of 2352 images in eight processed
# 200 of 2352 images in eight processed
# 300 of 2352 images in eight processed
# 400 of 2352 images in eight processed
# 500 of 2352 images in eight processed
# 600 of 2352 images in eight processed
# 700 of 2352 images in eight processed
# 800 of 2352 images in eight processed
# 900 of 2352 images in eight processed
# 1000 of 2352 images in eight processed
# 1100 of 2352 images in eight processed
# 1200 of 2352 images in eight processed
# 1300 of 2352 images in eight processed
# 1400 of 2352 images in eight processed
# 1500 of 2352 images in eight processed
# 1600 of 2352 images in eight processed
# 1700 of 2352 images in eight processed
# 1800 of 2352 images in eight processed
# 1900 of 2352 images in eight processed
# 2000 of 2352 images in eight processed
# 2100 of 2352 images in eight processed
# 2200 of 2352 images in eight processed
# 2300 of 2352 images in eight processed
# file count in eight: 2352
# 0 of 1746 images in marvin processed
# 100 of 1746 images in marvin processed
# 200 of 1746 images in marvin processed
# 300 of 1746 images in marvin processed
# 400 of 1746 images in marvin processed
# 500 of 1746 images in marvin processed
# 600 of 1746 images in marvin processed
# 700 of 1746 images in marvin processed
# 800 of 1746 images in marvin processed
# 900 of 1746 images in marvin processed
# 1000 of 1746 images in marvin processed
# 1100 of 1746 images in marvin processed
# 1200 of 1746 images in marvin processed
# 1300 of 1746 images in marvin processed
# 1400 of 1746 images in marvin processed
# 1500 of 1746 images in marvin processed
# 1600 of 1746 images in marvin processed
# 1700 of 1746 images in marvin processed
# file count in marvin: 1746
# 0 of 2380 images in stop processed
# 100 of 2380 images in stop processed
# 200 of 2380 images in stop processed
# 300 of 2380 images in stop processed
# 400 of 2380 images in stop processed
# 500 of 2380 images in stop processed
# 600 of 2380 images in stop processed
# 700 of 2380 images in stop processed
# 800 of 2380 images in stop processed
# 900 of 2380 images in stop processed
# 1000 of 2380 images in stop processed
# 1100 of 2380 images in stop processed
# 1200 of 2380 images in stop processed
# 1300 of 2380 images in stop processed
# 1400 of 2380 images in stop processed
# 1500 of 2380 images in stop processed
# 1600 of 2380 images in stop processed
# 1700 of 2380 images in stop processed
# 1800 of 2380 images in stop processed
# 1900 of 2380 images in stop processed
# 2000 of 2380 images in stop processed
# 2100 of 2380 images in stop processed
# 2200 of 2380 images in stop processed
# 2300 of 2380 images in stop processed
# file count in stop: 2380
# 0 of 2377 images in yes processed
# 100 of 2377 images in yes processed
# 200 of 2377 images in yes processed
# 300 of 2377 images in yes processed
# 400 of 2377 images in yes processed
# 500 of 2377 images in yes processed
# 600 of 2377 images in yes processed
# 700 of 2377 images in yes processed
# 800 of 2377 images in yes processed
# 900 of 2377 images in yes processed
# 1000 of 2377 images in yes processed
# 1100 of 2377 images in yes processed
# 1200 of 2377 images in yes processed
# 1300 of 2377 images in yes processed
# 1400 of 2377 images in yes processed
# 1500 of 2377 images in yes processed
# 1600 of 2377 images in yes processed
# 1700 of 2377 images in yes processed
# 1800 of 2377 images in yes processed
# 1900 of 2377 images in yes processed
# 2000 of 2377 images in yes processed
# 2100 of 2377 images in yes processed
# 2200 of 2377 images in yes processed
# 2300 of 2377 images in yes processed
# file count in yes: 2377
# 0 of 2356 images in three processed
# 100 of 2356 images in three processed
# 200 of 2356 images in three processed
# 300 of 2356 images in three processed
# 400 of 2356 images in three processed
# 500 of 2356 images in three processed
# 600 of 2356 images in three processed
# 700 of 2356 images in three processed
# 800 of 2356 images in three processed
# 900 of 2356 images in three processed
# 1000 of 2356 images in three processed
# 1100 of 2356 images in three processed
# 1200 of 2356 images in three processed
# 1300 of 2356 images in three processed
# 1400 of 2356 images in three processed
# 1500 of 2356 images in three processed
# 1600 of 2356 images in three processed
# 1700 of 2356 images in three processed
# 1800 of 2356 images in three processed
# 1900 of 2356 images in three processed
# 2000 of 2356 images in three processed
# 2100 of 2356 images in three processed
# 2200 of 2356 images in three processed
# 2300 of 2356 images in three processed
# file count in three: 2356
# 0 of 2359 images in down processed
# 100 of 2359 images in down processed
# 200 of 2359 images in down processed
# 300 of 2359 images in down processed
# 400 of 2359 images in down processed
# 500 of 2359 images in down processed
# 600 of 2359 images in down processed
# 700 of 2359 images in down processed
# 800 of 2359 images in down processed
# 900 of 2359 images in down processed
# 1000 of 2359 images in down processed
# 1100 of 2359 images in down processed
# 1200 of 2359 images in down processed
# 1300 of 2359 images in down processed
# 1400 of 2359 images in down processed
# 1500 of 2359 images in down processed
# 1600 of 2359 images in down processed
# 1700 of 2359 images in down processed
# 1800 of 2359 images in down processed
# 1900 of 2359 images in down processed
# 2000 of 2359 images in down processed
# 2100 of 2359 images in down processed
# 2200 of 2359 images in down processed
# 2300 of 2359 images in down processed
# file count in down: 2359
# 0 of 2364 images in nine processed
# 100 of 2364 images in nine processed
# 200 of 2364 images in nine processed
# 300 of 2364 images in nine processed
# 400 of 2364 images in nine processed
# 500 of 2364 images in nine processed
# 600 of 2364 images in nine processed
# 700 of 2364 images in nine processed
# 800 of 2364 images in nine processed
# 900 of 2364 images in nine processed
# 1000 of 2364 images in nine processed
# 1100 of 2364 images in nine processed
# 1200 of 2364 images in nine processed
# 1300 of 2364 images in nine processed
# 1400 of 2364 images in nine processed
# 1500 of 2364 images in nine processed
# 1600 of 2364 images in nine processed
# 1700 of 2364 images in nine processed
# 1800 of 2364 images in nine processed
# 1900 of 2364 images in nine processed
# 2000 of 2364 images in nine processed
# 2100 of 2364 images in nine processed
# 2200 of 2364 images in nine processed
# 2300 of 2364 images in nine processed
# file count in nine: 2364
# 0 of 2372 images in four processed
# 100 of 2372 images in four processed
# 200 of 2372 images in four processed
# 300 of 2372 images in four processed
# 400 of 2372 images in four processed
# 500 of 2372 images in four processed
# 600 of 2372 images in four processed
# 700 of 2372 images in four processed
# 800 of 2372 images in four processed
# 900 of 2372 images in four processed
# 1000 of 2372 images in four processed
# 1100 of 2372 images in four processed
# 1200 of 2372 images in four processed
# 1300 of 2372 images in four processed
# 1400 of 2372 images in four processed
# 1500 of 2372 images in four processed
# 1600 of 2372 images in four processed
# 1700 of 2372 images in four processed
# 1800 of 2372 images in four processed
# 1900 of 2372 images in four processed
# 2000 of 2372 images in four processed
# 2100 of 2372 images in four processed
# 2200 of 2372 images in four processed
# 2300 of 2372 images in four processed
# file count in four: 2372
# 0 of 2377 images in seven processed
# 100 of 2377 images in seven processed
# 200 of 2377 images in seven processed
# 300 of 2377 images in seven processed
# 400 of 2377 images in seven processed
# 500 of 2377 images in seven processed
# 600 of 2377 images in seven processed
# 700 of 2377 images in seven processed
# 800 of 2377 images in seven processed
# 900 of 2377 images in seven processed
# 1000 of 2377 images in seven processed
# 1100 of 2377 images in seven processed
# 1200 of 2377 images in seven processed
# 1300 of 2377 images in seven processed
# 1400 of 2377 images in seven processed
# 1500 of 2377 images in seven processed
# 1600 of 2377 images in seven processed
# 1700 of 2377 images in seven processed
# 1800 of 2377 images in seven processed
# 1900 of 2377 images in seven processed
# 2000 of 2377 images in seven processed
# 2100 of 2377 images in seven processed
# 2200 of 2377 images in seven processed
# 2300 of 2377 images in seven processed
# file count in seven: 2377
# 0 of 1734 images in sheila processed
# 100 of 1734 images in sheila processed
# 200 of 1734 images in sheila processed
# 300 of 1734 images in sheila processed
# 400 of 1734 images in sheila processed
# 500 of 1734 images in sheila processed
# 600 of 1734 images in sheila processed
# 700 of 1734 images in sheila processed
# 800 of 1734 images in sheila processed
# 900 of 1734 images in sheila processed
# 1000 of 1734 images in sheila processed
# 1100 of 1734 images in sheila processed
# 1200 of 1734 images in sheila processed
# 1300 of 1734 images in sheila processed
# 1400 of 1734 images in sheila processed
# 1500 of 1734 images in sheila processed
# 1600 of 1734 images in sheila processed
# 1700 of 1734 images in sheila processed
# file count in sheila: 1734
# 0 of 1746 images in dog processed
# 100 of 1746 images in dog processed
# 200 of 1746 images in dog processed
# 300 of 1746 images in dog processed
# 400 of 1746 images in dog processed
# 500 of 1746 images in dog processed
# 600 of 1746 images in dog processed
# 700 of 1746 images in dog processed
# 800 of 1746 images in dog processed
# 900 of 1746 images in dog processed
# 1000 of 1746 images in dog processed
# 1100 of 1746 images in dog processed
# 1200 of 1746 images in dog processed
# 1300 of 1746 images in dog processed
# 1400 of 1746 images in dog processed
# 1500 of 1746 images in dog processed
# 1600 of 1746 images in dog processed
# 1700 of 1746 images in dog processed
# file count in dog: 1746
# 0 of 2367 images in right processed
# 100 of 2367 images in right processed
# 200 of 2367 images in right processed
# 300 of 2367 images in right processed
# 400 of 2367 images in right processed
# 500 of 2367 images in right processed
# 600 of 2367 images in right processed
# 700 of 2367 images in right processed
# 800 of 2367 images in right processed
# 900 of 2367 images in right processed
# 1000 of 2367 images in right processed
# 1100 of 2367 images in right processed
# 1200 of 2367 images in right processed
# 1300 of 2367 images in right processed
# 1400 of 2367 images in right processed
# 1500 of 2367 images in right processed
# 1600 of 2367 images in right processed
# 1700 of 2367 images in right processed
# 1800 of 2367 images in right processed
# 1900 of 2367 images in right processed
# 2000 of 2367 images in right processed
# 2100 of 2367 images in right processed
# 2200 of 2367 images in right processed
# 2300 of 2367 images in right processed
# file count in right: 2367
# 0 of 2373 images in two processed
# 100 of 2373 images in two processed
# 200 of 2373 images in two processed
# 300 of 2373 images in two processed
# 400 of 2373 images in two processed
# 500 of 2373 images in two processed
# 600 of 2373 images in two processed
# 700 of 2373 images in two processed
# 800 of 2373 images in two processed
# 900 of 2373 images in two processed
# 1000 of 2373 images in two processed
# 1100 of 2373 images in two processed
# 1200 of 2373 images in two processed
# 1300 of 2373 images in two processed
# 1400 of 2373 images in two processed
# 1500 of 2373 images in two processed
# 1600 of 2373 images in two processed
# 1700 of 2373 images in two processed
# 1800 of 2373 images in two processed
# 1900 of 2373 images in two processed
# 2000 of 2373 images in two processed
# 2100 of 2373 images in two processed
# 2200 of 2373 images in two processed
# 2300 of 2373 images in two processed
# file count in two: 2373
# 0 of 1745 images in wow processed
# 100 of 1745 images in wow processed
# 200 of 1745 images in wow processed
# 300 of 1745 images in wow processed
# 400 of 1745 images in wow processed
# 500 of 1745 images in wow processed
# 600 of 1745 images in wow processed
# 700 of 1745 images in wow processed
# 800 of 1745 images in wow processed
# 900 of 1745 images in wow processed
# 1000 of 1745 images in wow processed
# 1100 of 1745 images in wow processed
# 1200 of 1745 images in wow processed
# 1300 of 1745 images in wow processed
# 1400 of 1745 images in wow processed
# 1500 of 1745 images in wow processed
# 1600 of 1745 images in wow processed
# 1700 of 1745 images in wow processed
# file count in wow: 1745
# 0 of 1750 images in house processed
# 100 of 1750 images in house processed
# 200 of 1750 images in house processed
# 300 of 1750 images in house processed
# 400 of 1750 images in house processed
# 500 of 1750 images in house processed
# 600 of 1750 images in house processed
# 700 of 1750 images in house processed
# 800 of 1750 images in house processed
# 900 of 1750 images in house processed
# 1000 of 1750 images in house processed
# 1100 of 1750 images in house processed
# 1200 of 1750 images in house processed
# 1300 of 1750 images in house processed
# 1400 of 1750 images in house processed
# 1500 of 1750 images in house processed
# 1600 of 1750 images in house processed
# 1700 of 1750 images in house processed
# file count in house: 1750
# 0 of 1731 images in bird processed
# 100 of 1731 images in bird processed
# 200 of 1731 images in bird processed
# 300 of 1731 images in bird processed
# 400 of 1731 images in bird processed
# 500 of 1731 images in bird processed
# 600 of 1731 images in bird processed
# 700 of 1731 images in bird processed
# 800 of 1731 images in bird processed
# 900 of 1731 images in bird processed
# 1000 of 1731 images in bird processed
# 1100 of 1731 images in bird processed
# 1200 of 1731 images in bird processed
# 1300 of 1731 images in bird processed
# 1400 of 1731 images in bird processed
# 1500 of 1731 images in bird processed
# 1600 of 1731 images in bird processed
# 1700 of 1731 images in bird processed
# file count in bird: 1731
# 0 of 2357 images in five processed
# 100 of 2357 images in five processed
# 200 of 2357 images in five processed
# 300 of 2357 images in five processed
# 400 of 2357 images in five processed
# 500 of 2357 images in five processed
# 600 of 2357 images in five processed
# 700 of 2357 images in five processed
# 800 of 2357 images in five processed
# 900 of 2357 images in five processed
# 1000 of 2357 images in five processed
# 1100 of 2357 images in five processed
# 1200 of 2357 images in five processed
# 1300 of 2357 images in five processed
# 1400 of 2357 images in five processed
# 1500 of 2357 images in five processed
# 1600 of 2357 images in five processed
# 1700 of 2357 images in five processed
# 1800 of 2357 images in five processed
# 1900 of 2357 images in five processed
# 2000 of 2357 images in five processed
# 2100 of 2357 images in five processed
# 2200 of 2357 images in five processed
# 2300 of 2357 images in five processed
# file count in five: 2357
# total file count: 64727
# CPU times: user 5min 19s, sys: 11.5 s, total: 5min 30s
# Wall time: 10min 15s

# %%
# fig = plt.figure(figsize=(14, 8))
# ax1 = fig.add_subplot(211)
# ax1.set_title('Raw wave of ' + filename)
# ax1.set_ylabel('Amplitude')
# ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
#ONE IMAGE TEST
one_file = './train/audio/bird/66041c69_nohash_0.wav'
tmp = './train/spect_tmp/66041c69_nohash_0_tmp.jpg'
spect = './train/spect/66041c69_nohash_0_spect.jpg'


sample_rate, samples = wavfile.read(one_file)
_, spectrogram = log_specgram(samples, sample_rate)

#plt.imshow(spectrogram.T, aspect='auto', origin='lower')

plt.imsave(tmp, spectrogram.T, origin='lower')
#plt.imsave(tmp, spectrogram.T)
#plt.axis('off')


# freqs, times, spectrogram = log_specgram(samples, sample_rate)
# mean = np.mean(spectrogram, axis=0)
# std = np.std(spectrogram, axis=0)
# spectrogram = (spectrogram - mean) / std


# fig = plt.figure(figsize=(14, 8))
# #ax2 = fig.add_subplot(211)
# plt.imsave(spectrogram)
# plt.imsave(spectrogram.T, aspect='auto', origin='lower', 
#            extent=[times.min(), times.max(), freqs.min(), freqs.max()])

# ax2.set_yticks(freqs[::16])
# ax2.set_xticks(times[::16])
# ax2.set_title('Spectrogram of ' + filename)
# ax2.set_ylabel('Freqs in Hz')
# ax2.set_xlabel('Seconds')
# plt.axis('off')
# ax2.set_axis_off()
#plt.savefig('spect003.png', bbox_inches='tight', transparent=True)
#plt.close(fig)
#fig.clf()

# size = 224, 224
# im = Image.open(tmp_img).resize(size)
# os.remove(tmp_img)
# im.save(spect_img)

# %%
image = Image.open(tmp)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=99x161 at 0x7F8D4E64DB70>

# %%
image.resize([96, 96])
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7F8D4E651278>

# %%
Image.open('./train/spect/cat/4f2be90f_nohash_0_spect.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F286D631DD8>
